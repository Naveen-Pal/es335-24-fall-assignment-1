# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from base import DecisionTree
from metrics import *

np.random.seed(42)

# %%
N = 30
P = 5
X = pd.DataFrame(np.random.randn(N, P))
y = pd.Series(np.random.randn(N))

# %% [markdown]
# REAL INPUT AND REAL OUTPUT

# %%
for criteria in ["information_gain", "gini_index"]:
    print(f"Running Decision Tree with {criteria} criterion...\n")
    tree = DecisionTree()
    tree.fit(X, y)
    y_hat = tree.predict(X)
    tree.plot()
    print(f"Criteria: {criteria}")
    print("RMSE:", rmse(y_hat, y))
    print("MAE:", mae(y_hat, y))
# Out:
# Running Decision Tree with information_gain criterion...
#
#  [2 <= 0.674252023587605]
#     [3 <= 0.7889120340559967]
#        [2 <= -0.29307759077898854]
#           [0 <= 1.1613310755634525]
#              [0 <= -0.38171895281445334]
#                 Decision: -1.8308153741936848
#              [0 > -0.38171895281445334]
#                 Decision: -2.245667198993836
#           [0 > 1.1613310755634525]
#              Decision: -0.8783711870927843
#        [2 > -0.29307759077898854]
#           [1 <= 1.9025179131435808]
#              [4 <= -1.5445374280655955]
#                 Decision: -1.6990072048436677
#              [4 > -1.5445374280655955]
#                 Decision: -0.3627718931380622
#           [1 > 1.9025179131435808]
#              Decision: -1.7618637420397385
#     [3 > 0.7889120340559967]
#        [2 <= -1.3424972483641633]
#           [0 <= -0.1982853129157069]
#              Decision: -0.6309921298739474
#           [0 > -0.1982853129157069]
#              [0 <= 0.2029685381040715]
#                 Decision: -0.5011399672785699
#              [0 > 0.2029685381040715]
#                 Decision: -0.47637770096936727
#        [2 > -1.3424972483641633]
#           [2 <= -0.07144180732177668]
#              [0 <= -1.864981692025823]
#                 Decision: 0.22964517693797995
#              [0 > -1.864981692025823]
#                 Decision: 0.5118301080707781
#           [2 > -0.07144180732177668]
#              [1 <= 2.0378689800153156]
#                 Decision: -0.18428470160498764
#              [1 > 2.0378689800153156]
#                 Decision: -0.06902251499622762
#  [2 > 0.674252023587605]
#     [3 <= 0.6580208925330899]
#        [0 <= 1.1688017783944264]
#           [4 <= 1.1145837673873162]
#              [0 <= -0.0017000921855904044]
#                 Decision: -0.9542942363875251
#              [0 > -0.0017000921855904044]
#                 Decision: 0.12515469706288854
#           [4 > 1.1145837673873162]
#              [0 <= 0.12089573848737994]
#                 Decision: 0.5714806965769847
#              [0 > 0.12089573848737994]
#                 Decision: 0.5081897774921301
#        [0 > 1.1688017783944264]
#           Decision: 2.501698212860443
#     [3 > 0.6580208925330899]
#        [0 <= -0.2433856124481661]
#           Decision: 3.1673716720641596
#        [0 > -0.2433856124481661]
#           Decision: 2.235674686984474
# Criteria: information_gain
# RMSE: 0.9996192596778077
# MAE: 0.7666712302826993
# Running Decision Tree with gini_index criterion...
#
#  [2 <= 0.674252023587605]
#     [3 <= 0.7889120340559967]
#        [2 <= -0.29307759077898854]
#           [0 <= 1.1613310755634525]
#              [0 <= -0.38171895281445334]
#                 Decision: -1.8308153741936848
#              [0 > -0.38171895281445334]
#                 Decision: -2.245667198993836
#           [0 > 1.1613310755634525]
#              Decision: -0.8783711870927843
#        [2 > -0.29307759077898854]
#           [1 <= 1.9025179131435808]
#              [4 <= -1.5445374280655955]
#                 Decision: -1.6990072048436677
#              [4 > -1.5445374280655955]
#                 Decision: -0.3627718931380622
#           [1 > 1.9025179131435808]
#              Decision: -1.7618637420397385
#     [3 > 0.7889120340559967]
#        [2 <= -1.3424972483641633]
#           [0 <= -0.1982853129157069]
#              Decision: -0.6309921298739474
#           [0 > -0.1982853129157069]
#              [0 <= 0.2029685381040715]
#                 Decision: -0.5011399672785699
#              [0 > 0.2029685381040715]
#                 Decision: -0.47637770096936727
#        [2 > -1.3424972483641633]
#           [2 <= -0.07144180732177668]
#              [0 <= -1.864981692025823]
#                 Decision: 0.22964517693797995
#              [0 > -1.864981692025823]
#                 Decision: 0.5118301080707781
#           [2 > -0.07144180732177668]
#              [1 <= 2.0378689800153156]
#                 Decision: -0.18428470160498764
#              [1 > 2.0378689800153156]
#                 Decision: -0.06902251499622762
#  [2 > 0.674252023587605]
#     [3 <= 0.6580208925330899]
#        [0 <= 1.1688017783944264]
#           [4 <= 1.1145837673873162]
#              [0 <= -0.0017000921855904044]
#                 Decision: -0.9542942363875251
#              [0 > -0.0017000921855904044]
#                 Decision: 0.12515469706288854
#           [4 > 1.1145837673873162]
#              [0 <= 0.12089573848737994]
#                 Decision: 0.5714806965769847
#              [0 > 0.12089573848737994]
#                 Decision: 0.5081897774921301
#        [0 > 1.1688017783944264]
#           Decision: 2.501698212860443
#     [3 > 0.6580208925330899]
#        [0 <= -0.2433856124481661]
#           Decision: 3.1673716720641596
#        [0 > -0.2433856124481661]
#           Decision: 2.235674686984474
# Criteria: gini_index
# RMSE: 0.9996192596778077
# MAE: 0.7666712302826993

# %% [markdown]
# REAL INPUT AND DISCRETE OUTPUT

# %%
X = pd.DataFrame(np.random.randn(N, P))
y = pd.Series(np.random.randint(P, size=N), dtype="category")

for criteria in ["information_gain", "gini_index"]:
    print(f"Running Decision Tree with {criteria} criterion...\n")
    tree = DecisionTree(criterion=criteria)
    tree.fit(X, y)
    y_hat = tree.predict(X)
    tree.plot()
    print(f"Criteria: {criteria}")
    print("Accuracy:", accuracy(y_hat, y))
    for cls in y.unique():
        print(f"Class {cls} - Precision:", precision(y_hat, y, cls))
        print(f"Class {cls} - Recall:", recall(y_hat, y, cls))
# Out:
# Running Decision Tree with information_gain criterion...
#
#  [1 <= -0.1291699916066525]
#     [0 <= -0.2351340565712592]
#        [2 <= 0.9031349022374484]
#           [4 <= 0.37304869258456097]
#              Decision: 3
#           [4 > 0.37304869258456097]
#              Decision: 0
#        [2 > 0.9031349022374484]
#           Decision: 2
#     [0 > -0.2351340565712592]
#        [0 <= 0.17573481274179076]
#           [0 <= -0.1862932275219108]
#              Decision: 1
#           [0 > -0.1862932275219108]
#              Decision: 2
#        [0 > 0.17573481274179076]
#           Decision: 1
#  [1 > -0.1291699916066525]
#     [2 <= -0.27238126516092]
#        [1 <= 0.4220911753473172]
#           Decision: 4
#        [1 > 0.4220911753473172]
#           [1 <= 1.8564329878755206]
#              Decision: 1
#           [1 > 1.8564329878755206]
#              Decision: 4
#     [2 > -0.27238126516092]
#        [4 <= -0.6043864417715281]
#           [0 <= -0.1173285103074535]
#              Decision: 0
#           [0 > -0.1173285103074535]
#              Decision: 1
#        [4 > -0.6043864417715281]
#           [3 <= 0.16865389994512917]
#              [0 <= -0.10928731292802657]
#                 Decision: 3
#              [0 > -0.10928731292802657]
#                 Decision: 4
#           [3 > 0.16865389994512917]
#              Decision: 3
# Criteria: information_gain
# Accuracy: 0.3333333333333333
# Class 3 - Precision: 0.0
# Class 3 - Recall: 0.0
# Class 4 - Precision: 0.0
# Class 4 - Recall: 0.0
# Class 1 - Precision: 0.2857142857142857
# Class 1 - Recall: 1.0
# Class 0 - Precision: 1.0
# Class 0 - Recall: 0.6666666666666666
# Class 2 - Precision: 0.0
# Class 2 - Recall: 0.0
# Running Decision Tree with gini_index criterion...
#
#  [1 <= -1.0884316556906155]
#     Decision: 1
#  [1 > -1.0884316556906155]
#     [4 <= 1.6194366186824096]
#        [4 <= -1.4392170754768852]
#           Decision: 1
#        [4 > -1.4392170754768852]
#           [1 <= -0.14709796543198866]
#              [0 <= -0.2173967031121094]
#                 Decision: 3
#              [0 > -0.2173967031121094]
#                 Decision: 2
#           [1 > -0.14709796543198866]
#              [2 <= -0.6866980563364403]
#                 Decision: 1
#              [2 > -0.6866980563364403]
#                 Decision: 3
#     [4 > 1.6194366186824096]
#        [0 <= 0.6759447197713411]
#           [0 <= 0.09674478042408291]
#              Decision: 4
#           [0 > 0.09674478042408291]
#              Decision: 1
#        [0 > 0.6759447197713411]
#           Decision: 4
# Criteria: gini_index
# Accuracy: 0.26666666666666666
# Class 3 - Precision: 0.0
# Class 3 - Recall: 0.0
# Class 4 - Precision: 0.0
# Class 4 - Recall: 0.0
# Class 1 - Precision: 0.26666666666666666
# Class 1 - Recall: 1.0
# Class 0 - Precision: 0.0
# Class 0 - Recall: 0.0
# Class 2 - Precision: 0.0
# Class 2 - Recall: 0.0

# %% [markdown]
# DISCRETE INPUT AND DISCRETE OUTPUT

# %%
X = pd.DataFrame({i: pd.Series(np.random.randint(P, size=N), dtype="category") for i in range(5)})
y = pd.Series(np.random.randint(P, size=N), dtype="category")

for criteria in ["information_gain", "gini_index"]:
    print(f"Running Decision Tree with {criteria} criterion...\n")
    
    # Initialize the tree with the chosen criterion
    tree = DecisionTree(criterion=criteria)
    
    # Fit the tree (no need to pass criterion here again)
    tree.fit(X, y)
    
    # Predict and evaluate
    y_hat = tree.predict(X)
    
    # Plot the tree
    tree.plot()
    
    # Print evaluation metrics
    print(f"Criteria: {criteria}")
    print("Accuracy:", accuracy(y_hat, y))
    for cls in y.unique():
        print(f"Class {cls} - Precision:", precision(y_hat, y, cls))
        print(f"Class {cls} - Recall:", recall(y_hat, y, cls))
# Out:
# Running Decision Tree with information_gain criterion...
#
#  [3]
#  - 3:
#     [0]
#     - 2:
#        [1]
#        - 2:
#           Decision: 0
#        - 0:
#           Decision: 1
#     - 3:
#        Decision: 1
#     - 1:
#        Decision: 3
#     - 0:
#        Decision: 4
#  - 4:
#     [2]
#     - 0:
#        Decision: 3
#     - 2:
#        Decision: 0
#     - 4:
#        Decision: 0
#     - 1:
#        Decision: 3
#     - 3:
#        Decision: 4
#  - 1:
#     [1]
#     - 1:
#        Decision: 4
#     - 3:
#        [2]
#        - 1:
#           Decision: 2
#        - 0:
#           Decision: 1
#     - 0:
#        [2]
#        - 0:
#           Decision: 4
#        - 4:
#           Decision: 2
#        - 3:
#           Decision: 2
#     - 2:
#        Decision: 1
#     - 4:
#        Decision: 1
#  - 0:
#     [4]
#     - 0:
#        [2]
#        - 4:
#           Decision: 0
#        - 0:
#           Decision: 3
#     - 4:
#        [0]
#        - 0:
#           Decision: 3
#        - 3:
#           Decision: 4
#     - 3:
#        Decision: 0
#     - 1:
#        Decision: 4
#     - 2:
#        Decision: 1
#  - 2:
#     [1]
#     - 3:
#        Decision: 2
#     - 0:
#        Decision: 1
#     - 4:
#        Decision: 0
# Criteria: information_gain
# Accuracy: 0.4666666666666667
# Class 0 - Precision: 1.0
# Class 0 - Recall: 1.0
# Class 3 - Precision: 0.0
# Class 3 - Recall: 0.0
# Class 1 - Precision: 0.30434782608695654
# Class 1 - Recall: 1.0
# Class 4 - Precision: 0.0
# Class 4 - Recall: 0.0
# Class 2 - Precision: 0.0
# Class 2 - Recall: 0.0
# Running Decision Tree with gini_index criterion...
#
#  [1]
#  - 2:
#     [3]
#     - 3:
#        Decision: 0
#     - 4:
#        Decision: 0
#     - 1:
#        Decision: 1
#     - 0:
#        Decision: 1
#  - 1:
#     [2]
#     - 0:
#        Decision: 3
#     - 3:
#        Decision: 4
#  - 4:
#     [0]
#     - 3:
#        Decision: 1
#     - 4:
#        Decision: 0
#     - 0:
#        [2]
#        - 3:
#           Decision: 1
#        - 4:
#           Decision: 0
#     - 1:
#        Decision: 4
#  - 3:
#     [3]
#     - 1:
#        [2]
#        - 1:
#           Decision: 2
#        - 0:
#           Decision: 1
#     - 0:
#        [0]
#        - 4:
#           [2]
#           - 4:
#              Decision: 0
#           - 0:
#              Decision: 3
#        - 3:
#           Decision: 4
#     - 4:
#        [0]
#        - 3:
#           Decision: 0
#        - 2:
#           Decision: 3
#     - 2:
#        Decision: 2
#     - 3:
#        Decision: 4
#  - 0:
#     [2]
#     - 4:
#        [0]
#        - 1:
#           Decision: 3
#        - 4:
#           Decision: 2
#     - 0:
#        [0]
#        - 4:
#           Decision: 4
#        - 0:
#           Decision: 3
#     - 3:
#        Decision: 2
#     - 2:
#        Decision: 1
#     - 1:
#        Decision: 1
# Criteria: gini_index
# Accuracy: 0.4666666666666667
# Class 0 - Precision: 1.0
# Class 0 - Recall: 1.0
# Class 3 - Precision: 0.0
# Class 3 - Recall: 0.0
# Class 1 - Precision: 0.30434782608695654
# Class 1 - Recall: 1.0
# Class 4 - Precision: 0.0
# Class 4 - Recall: 0.0
# Class 2 - Precision: 0.0
# Class 2 - Recall: 0.0

# %% [markdown]
# DISCRETE INPUT AND REAL OUTPUT

# %%
X = pd.DataFrame({i: pd.Series(np.random.randint(P, size=N), dtype="category") for i in range(5)})
y = pd.Series(np.random.randn(N))

for criteria in ["information_gain", "gini_index"]:
    print(f"Running Decision Tree with {criteria} criterion...\n")
    tree = DecisionTree(criterion=criteria)
    tree.fit(X, y)
    y_hat = tree.predict(X)
    tree.plot()
    print(f"Criteria: {criteria}")
    print("RMSE:", rmse(y_hat, y))
    print("MAE:", mae(y_hat, y))
# Out:
# Running Decision Tree with information_gain criterion...
#
#  [3]
#  - 4:
#     [0]
#     - 1:
#        Decision: 0.09643371879348994
#     - 3:
#        [1]
#        - 3:
#           [0]
#           - 3:
#              [0]
#              - 3:
#                 Decision: -0.7590808561257798
#        - 0:
#           Decision: -1.6010192977017523
#     - 2:
#        [1]
#        - 1:
#           Decision: 1.3140094746438993
#        - 4:
#           Decision: 0.7080891218566765
#     - 4:
#        Decision: -1.2145434897264067
#     - 0:
#        Decision: 0.07518708760618616
#  - 0:
#     [2]
#     - 0:
#        [0]
#        - 4:
#           Decision: -0.6808872820390818
#        - 2:
#           Decision: -0.3067803928713705
#     - 4:
#        Decision: -0.5339091013167999
#     - 3:
#        [0]
#        - 2:
#           Decision: -1.4071440262149164
#        - 4:
#           Decision: 0.5037360462124257
#     - 2:
#        Decision: 0.3616765854236551
#  - 2:
#     [0]
#     - 3:
#        [1]
#        - 1:
#           Decision: 0.6294135848867876
#        - 4:
#           Decision: 0.7800781797165829
#     - 1:
#        Decision: 0.0812768427670279
#     - 2:
#        [1]
#        - 4:
#           Decision: -0.7491792406291301
#        - 0:
#           Decision: 0.5823959599840627
#     - 4:
#        Decision: -0.8897461017865688
#  - 3:
#     [0]
#     - 2:
#        Decision: -0.9149590677826966
#     - 1:
#        Decision: -1.070594338235602
#     - 3:
#        Decision: -0.7042877081911889
#     - 4:
#        Decision: -0.8480986993392317
#  - 1:
#     [2]
#     - 1:
#        [0]
#        - 3:
#           Decision: 1.5834650253840938
#        - 4:
#           Decision: 0.07299675597335759
#     - 3:
#        Decision: 1.227050059970152
#     - 0:
#        [0]
#        - 2:
#           Decision: 0.22534275368906728
#        - 4:
#           Decision: -0.23888074786659733
#     - 2:
#        Decision: 0.08718640420643022
# Criteria: information_gain
# RMSE: 0.6862397858547548
# MAE: 0.5533034340584576
# Running Decision Tree with gini_index criterion...
#
#  [0]
#  - 1:
#     [1]
#     - 2:
#        Decision: 0.09643371879348994
#     - 0:
#        Decision: 0.0812768427670279
#     - 3:
#        Decision: -1.070594338235602
#  - 4:
#     [1]
#     - 1:
#        [2]
#        - 0:
#           Decision: -0.6808872820390818
#        - 1:
#           Decision: 0.07299675597335759
#     - 0:
#        Decision: -1.2145434897264067
#     - 2:
#        [2]
#        - 4:
#           Decision: -0.5339091013167999
#        - 0:
#           Decision: -0.23888074786659733
#     - 3:
#        [2]
#        - 2:
#           Decision: 0.3616765854236551
#        - 3:
#           Decision: 0.5037360462124257
#        - 1:
#           Decision: -0.8480986993392317
#     - 4:
#        Decision: -0.8897461017865688
#  - 3:
#     [2]
#     - 1:
#        [1]
#        - 3:
#           [0]
#           - 3:
#              [0]
#              - 3:
#                 Decision: -0.7590808561257798
#        - 1:
#           Decision: 0.6294135848867876
#        - 4:
#           Decision: 1.5834650253840938
#     - 2:
#        [3]
#        - 2:
#           Decision: 0.7800781797165829
#        - 1:
#           Decision: 0.08718640420643022
#     - 3:
#        Decision: 1.227050059970152
#     - 4:
#        Decision: -0.7042877081911889
#     - 0:
#        Decision: -1.6010192977017523
#  - 2:
#     [3]
#     - 3:
#        Decision: -0.9149590677826966
#     - 0:
#        [2]
#        - 0:
#           Decision: -0.3067803928713705
#        - 3:
#           Decision: -1.4071440262149164
#     - 4:
#        [1]
#        - 1:
#           Decision: 1.3140094746438993
#        - 4:
#           Decision: 0.7080891218566765
#     - 2:
#        [1]
#        - 4:
#           Decision: -0.7491792406291301
#        - 0:
#           Decision: 0.5823959599840627
#     - 1:
#        Decision: 0.22534275368906728
#  - 0:
#     Decision: 0.07518708760618616
# Criteria: gini_index
# RMSE: 0.6862397858547548
# MAE: 0.5533034340584576
