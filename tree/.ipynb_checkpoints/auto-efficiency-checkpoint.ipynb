# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
from base import DecisionTree 
np.random.seed(42)

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data'
data = pd.read_csv(url, delim_whitespace=True, header=None,
                   names=["mpg", "cylinders", "displacement", "horsepower", "weight",
                          "acceleration", "model year", "origin", "car name"])
# Out:
# C:\Users\91798\AppData\Local\Temp\ipykernel_28268\3565470146.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(url, delim_whitespace=True, header=None,

# %%
data
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0      130.0  3504.0          12.0
# 1    15.0          8         350.0      165.0  3693.0          11.5
# 2    18.0          8         318.0      150.0  3436.0          11.0
# 3    16.0          8         304.0      150.0  3433.0          12.0
# 4    17.0          8         302.0      140.0  3449.0          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0      86.00  2790.0          15.6
# 394  44.0          4          97.0      52.00  2130.0          24.6
# 395  32.0          4         135.0      84.00  2295.0          11.6
# 396  28.0          4         120.0      79.00  2625.0          18.6
# 397  31.0          4         119.0      82.00  2720.0          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# 1            70       1          buick skylark 320
# 2            70       1         plymouth satellite
# 3            70       1              amc rebel sst
# 4            70       1                ford torino
# ..          ...     ...                        ...
# 393          82       1            ford mustang gl
# 394          82       2                  vw pickup
# 395          82       1              dodge rampage
# 396          82       1                ford ranger
# 397          82       1                 chevy s-10
#
# [398 rows x 9 columns]

# %%
print("Features:", data.columns)
data.info()
# Out:
# Features: Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model year', 'origin', 'car name'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    float64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
data = data[data['horsepower']!='?']
y = data['mpg']
X = data.drop(['mpg', 'car name'], axis=1)
X
# Out:
#      cylinders  displacement horsepower  weight  acceleration  model year  \
# 0            8         307.0      130.0  3504.0          12.0          70
# 1            8         350.0      165.0  3693.0          11.5          70
# 2            8         318.0      150.0  3436.0          11.0          70
# 3            8         304.0      150.0  3433.0          12.0          70
# 4            8         302.0      140.0  3449.0          10.5          70
# ..         ...           ...        ...     ...           ...         ...
# 393          4         140.0      86.00  2790.0          15.6          82
# 394          4          97.0      52.00  2130.0          24.6          82
# 395          4         135.0      84.00  2295.0          11.6          82
# 396          4         120.0      79.00  2625.0          18.6          82
# 397          4         119.0      82.00  2720.0          19.4          82
#
#      origin
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ..      ...
# 393       1
# 394       2
# 395       1
# 396       1
# 397       1
#
# [392 rows x 7 columns]

# %%
print(data['mpg'].nunique())
# Out:
# 127

# %%
print("Shape of X:", X.shape)
print("Shape of y:", y.shape)
# Out:
# Shape of X: (392, 7)
# Shape of y: (392,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
X_train.columns
# Out:
# Index(['cylinders', 'displacement', 'horsepower', 'weight', 'acceleration',
#        'model year', 'origin'],
#       dtype='object')

# %%
tree_custom = DecisionTree(criterion='information_gain', max_depth=5)
tree_custom.fit(X_train, y_train)
y_pred_custom = tree_custom.predict(X_test)
accuracy_custom = accuracy_score(y_test, y_pred_custom)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 2
#       1 tree_custom = DecisionTree(criterion='information_gain', max_depth=5)
# ----> 2 tree_custom.fit(X_train, y_train)
#       3 y_pred_custom = tree_custom.predict(X_test)
#       4 accuracy_custom = accuracy_score(y_test, y_pred_custom)
#
# File ~\OneDrive - iitgn.ac.in\Desktop\PROJECT_ML\es335-24-fall-assignment-1\tree\base.py:94, in DecisionTree.fit(self, X, y)
#      90         node.right_child = _build_tree(right_X, right_y, depth + 1)
#      92     return node
# ---> 94 self.Root = _build_tree(X, y, depth=0)
#
# File ~\OneDrive - iitgn.ac.in\Desktop\PROJECT_ML\es335-24-fall-assignment-1\tree\base.py:80, in DecisionTree.fit.<locals>._build_tree(X, y, depth)
#      76 else:
#      77     # Continuous feature
#      78     if check_ifreal(y):
#      79         # Real Input, Real Output
# ---> 80         best_feature, split_val = self.opt_split_real_mse(X, y)
#      81     else:
#      82         # Real Input, Discrete Output
#      83         best_feature, split_val = self.opt_split_real(X, y)
#
# File ~\OneDrive - iitgn.ac.in\Desktop\PROJECT_ML\es335-24-fall-assignment-1\tree\base.py:106, in DecisionTree.opt_split_real_mse(self, X, y)
#     104 for feature in X.columns:
#     105     sorted_values = np.sort(X[feature].unique())
# --> 106     split_candidates = (sorted_values[:-1] + sorted_values[1:]) / 2
#     108     for split_val in split_candidates:
#     109         left_y = y[X[feature] <= split_val]
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
